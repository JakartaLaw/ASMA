# %% [markdown]
# # Part 1 - Assignment 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
from sklearn.linear_model import LinearRegression

from modules.stock import Stock
from modules.portfolio import Portfolio
from modules.performance import Performance, CollectPerformance
from modules.cleandata import CleanData
from modules.fourfactormodel import FourFactorModel
from modules.fourfactorplotter import four_factor_plotter

# %matplotlib inline

# %% [markdown]
# # Preparation

# %%
stock = Stock()

# %% [markdown]
# # Question 1.1 - 1.2

# %% [markdown]
# ### bmit

# %%
s, d = stock.portfolio(kpi='bmit', highlow='high', return_dummy=True)
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12, d)
p0 = perf.get_performance('bmit high')

# %%
s, d = stock.portfolio(kpi='bmit', highlow='low', return_dummy=True)
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12, d)
p1 = perf.get_performance('bmit low')

# %%
s, d = stock.portfolio(kpi='bmit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
perf = Performance(p, 12, d)
p2 = perf.get_performance('bmit highlow')

# %% [markdown]
# ### momit

# %%
s, d = stock.portfolio(kpi='momit', highlow='high', return_dummy=True)
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12, d)
p3 = perf.get_performance('momit high')

# %%
s, d = stock.portfolio(kpi='momit', highlow='low', return_dummy=True)
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12, d)
p4 = perf.get_performance('momit low')

# %%
s, d = stock.portfolio(kpi='momit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12, d, sum_of_weights=2)
p5 = perf.get_performance('momit high/low')

# %%
q1_perf = CollectPerformance([p0, p1, p2, p3, p4, p5])
q1_perf()
# Out:
#                 avg months for stock  avg return  sharpe ratio  \
# index_name
# bmit high                  24.552786    0.085271      0.519232
# bmit low                   24.552786    0.054189      0.265777
# bmit highlow               49.105572    0.031082      0.180977
# momit high                 24.552786    0.098987      0.495019
# momit low                  24.552786    0.049807      0.236453
# momit high/low             49.105572    0.049180      0.243627
#
#                 std. deviation     t-stat
# index_name
# bmit high             0.164225  11.863051
# bmit low              0.203888   6.072289
# bmit highlow          0.171747   4.134848
# momit high            0.199966  11.309850
# momit low             0.210641   5.402317
# momit high/low        0.201866   5.566228

# %% [markdown]
# # Question 1.3

# %%
stock.composite_data('bmit', 'momit')

# %%
s= stock.portfolio(kpi='bmit_momit', highlow='high')
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12)
p0 = perf.get_performance('composite high')

# %%
s = stock.portfolio(kpi='bmit_momit', highlow='low')
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12)
p1 = perf.get_performance('composite low')

# %%
s= stock.portfolio(kpi='bmit_momit', highlow='highlow')
p = Portfolio.portfolio_return(s, sum_of_weights=2)
perf = Performance(p, 12)
p2 = perf.get_performance('composite high/low')

# %%
sb = stock.portfolio(kpi='bmit', highlow='highlow')
sm = stock.portfolio(kpi='momit', highlow='highlow')
pb = Portfolio.portfolio_return(sb, sum_of_weights=2)
pm = Portfolio.portfolio_return(sm, sum_of_weights=2)
p = Portfolio.fifty_fifty(pb, pm)
perf = Performance(p, 12)
p3 = perf.get_performance('fifty fifty')

# %%
q3_perf = CollectPerformance([p0, p1, p2, p3])
q3_perf()
# Out:
#                     avg return  sharpe ratio  std. deviation     t-stat
# index_name
# composite high        0.089310      0.556989        0.160345  12.725694
# composite low         0.033185      0.164571        0.201643   3.760016
# composite high/low    0.056126      0.409929        0.136915   9.365785
# fifty fifty           0.040131      0.467560        0.085831  10.682504

# %% [markdown]
# # Question 1.4

# %%
stock.industry_adjusted_data('bmit')
stock.industry_adjusted_data('momit')
stock.composite_data('adjusted_bmit', 'adjusted_momit')

# %%
s, d = stock.portfolio(kpi='adjusted_bmit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
perf = Performance(p, 12, d)
p0 = perf.get_performance('adjusted bmit high/low')

# %%
s, d = stock.portfolio(kpi='adjusted_momit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
perf = Performance(p, 12, d)
p1 = perf.get_performance('adjusted momit high/low')

# %%
s, d = stock.portfolio(kpi='adjusted_bmit_adjusted_momit', highlow='high', return_dummy=True)
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12, d)
p2 = perf.get_performance('composite adjusted high')

# %%
s, d = stock.portfolio(kpi='adjusted_bmit_adjusted_momit', highlow='low', return_dummy=True)
p = Portfolio.portfolio_return(s)
perf = Performance(p, 12, d)
p3 = perf.get_performance('composite adjusted low')

# %%
s, d = stock.portfolio(kpi='adjusted_bmit_adjusted_momit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
perf = Performance(p, 12, d)
p4 = perf.get_performance('composite adjusted high/low')

# %%
q3_perf = CollectPerformance([p0, p1, p2, p3, p4])
q3_perf()
# Out:
#                              avg months for stock  avg return  sharpe ratio  \
# index_name
# adjusted bmit high/low                  49.105572    0.037009      0.325323
# composite momit high/low                49.105572    0.024783      0.167955
# composite adjusted high                 24.552786    0.099110      0.586594
# composite adjusted low                  24.552786    0.045012      0.235327
# composite adjusted high/low             49.105572    0.054098      0.576088
#
#                              std. deviation     t-stat
# index_name
# adjusted bmit high/low             0.113762   7.432748
# composite momit high/low           0.147557   3.837314
# composite adjusted high            0.168959  13.402109
# composite adjusted low             0.191274   5.376589
# composite adjusted high/low        0.093906  13.162071

# %% [markdown]
# # Question 1.5

# %% [markdown]
# ### BMIT

# %%
s, d = stock.portfolio(kpi='bmit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
t = FourFactorModel(stock, p)

# %%
t.regress_model(model_name = 'BMIT')
res = t.get_results()
res
# Out:
#                   HML       MKT       SMB      WML  intercept        r2
# capm              NaN -0.255797       NaN      NaN   0.003958  0.055160
# four factor  1.198354 -0.033386 -0.149688 -0.38899   0.001432  0.770335

# %%
four_factor_plotter(t, 'BMIT', save=False)

# %% [markdown]
# ### MOMIT

# %%
s, d = stock.portfolio(kpi='momit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
t = FourFactorModel(stock, p)

# %%
t.regress_model(model_name = 'MOMIT')
res = t.get_results()
res
# Out:
#                   HML       MKT       SMB       WML  intercept        r2
# capm              NaN -0.093208       NaN       NaN   0.004597  0.005301
# four factor -0.152091 -0.020417  0.279543  1.144726  -0.003784  0.809781

# %%
four_factor_plotter(t, 'MOMIT', save=False)

# %% [markdown]
# ### Composite

# %%
s, d = stock.portfolio(kpi='bmit_momit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
t = FourFactorModel(stock, p)

# %%
t.regress_model(model_name = 'BMIT_MOMIT')
res = t.get_results()
res
# Out:
#                   HML       MKT       SMB       WML  intercept        r2
# capm              NaN -0.246583       NaN       NaN   0.005996  0.080655
# four factor  0.670962 -0.045301  0.117432  0.618948  -0.002068  0.635355

# %%
four_factor_plotter(t, 'Composite', save=False)

# %% [markdown]
# ### Fifty Fifty

# %%
sb = stock.portfolio(kpi='bmit', highlow='highlow')
sm = stock.portfolio(kpi='momit', highlow='highlow')
pb = Portfolio.portfolio_return(sb, sum_of_weights=2)
pm = Portfolio.portfolio_return(sm, sum_of_weights=2)
p = Portfolio.fifty_fifty(pb, pm)
t = FourFactorModel(stock, p)

# %%
t.regress_model(model_name = 'FiftyFifty')
res = t.get_results()
res
# Out:
#                   HML       MKT       SMB       WML  intercept        r2
# capm              NaN -0.174502       NaN       NaN   0.004277  0.102784
# four factor  0.523131 -0.026901  0.064927  0.377868  -0.001176  0.724884

# %%
four_factor_plotter(t, 'Fifty Fifty', save=False)

# %% [markdown]
# ### Industry Adjusted

# %%
s, d = stock.portfolio(kpi='adjusted_bmit_adjusted_momit', highlow='highlow', return_dummy=True)
p = Portfolio.portfolio_return(s, sum_of_weights=2)
t = FourFactorModel(stock, p)

# %%
t.regress_model(model_name = 'BMIT_MOMIT')
res = t.get_results()
res
# Out:
#                   HML       MKT       SMB       WML  intercept        r2
# capm              NaN -0.138274       NaN       NaN   0.005248  0.053914
# four factor  0.339661 -0.035314  0.130672  0.418853   0.000287  0.543640

# %%
four_factor_plotter(t, 'Industry Adjusted', save=False)
